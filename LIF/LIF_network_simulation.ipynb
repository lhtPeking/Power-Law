# %%
import numpy as np
import matplotlib.pyplot as plt

from utils import LIFNetwork_GaussianWeight, LIFNetwork_PowerLawWeight

# %%
# net_2 = LIFNetwork_GaussianWeight(N=1000, I_ext=1.5e-9, record_voltage=True)
# net_2.run()
# net_2.plot_raster()
# net_2.plot_voltage(max_neurons=1)

net_4 = LIFNetwork_GaussianWeight(N=4000, I_ext=1.6e-9, record_voltage=True)
net_4.run()
net_4.plot_raster()
net_4.plot_voltage(max_neurons=1)

# net_6 = LIFNetwork_GaussianWeight(N=1000, I_ext=1.7e-9, record_voltage=True)
# net_6.run()
# net_6.plot_raster()
# net_6.plot_voltage(max_neurons=1)

# net_7 = LIFNetwork_GaussianWeight(N=1000, I_ext=1.6e-9, record_voltage=True)
# net_7.run()
# net_7.plot_raster()
# net_7.plot_voltage(max_neurons=1)
# Out:
# step 100/1000, cumulative spikes = 2718
# step 200/1000, cumulative spikes = 6055
# step 300/1000, cumulative spikes = 9414
# step 400/1000, cumulative spikes = 12682
# step 500/1000, cumulative spikes = 15939
# step 600/1000, cumulative spikes = 19770
# step 700/1000, cumulative spikes = 22767
# step 800/1000, cumulative spikes = 26343
# step 900/1000, cumulative spikes = 29700
# step 1000/1000, cumulative spikes = 32990

# %% [markdown]
# I_ext=1.6e-9 to I_ext=2e-9 seems to be a good param.

# %%
net_4.analyze_covariance()
# Out:
# (array([[ 1.62825593e-05,  3.59968492e-06,  7.79544506e-07, ...,
#           1.96663106e-06,  2.89934225e-06, -3.68957103e-07],
#         [ 3.59968492e-06,  2.05493690e-05,  3.93570630e-06, ...,
#           1.68581017e-06,  5.68240925e-06,  3.76669739e-08],
#         [ 7.79544506e-07,  3.93570630e-06,  2.11904886e-05, ...,
#           9.82517085e-07,  1.74119795e-06,  1.29484073e-06],
#         ...,
#         [ 1.96663106e-06,  1.68581017e-06,  9.82517085e-07, ...,
#           1.34590750e-05,  3.98350507e-06,  2.93257056e-06],
#         [ 2.89934225e-06,  5.68240925e-06,  1.74119795e-06, ...,
#           3.98350507e-06,  1.82615184e-05, -5.70106865e-07],
#         [-3.68957103e-07,  3.76669739e-08,  1.29484073e-06, ...,
#           2.93257056e-06, -5.70106865e-07,  1.89783335e-05]]),
#  array([ 3.81410011e-03,  7.25299480e-04,  6.41256633e-04, ...,
#         -1.63396795e-19, -1.73201933e-19, -4.08554854e-19]),
#  array([ 3.59968492e-06,  7.79544506e-07,  5.90053925e-07, ...,
# ...

# %%
net_8 = LIFNetwork_PowerLawWeight(N=4000, w_scale=1e-10, I_ext=1.6e-9, record_voltage=True)
net_8.run()
net_8.plot_raster()
net_8.plot_voltage(max_neurons=1)
# Out:
# step 100/1000, cumulative spikes = 7224
# step 200/1000, cumulative spikes = 16443
# step 300/1000, cumulative spikes = 25120
# step 400/1000, cumulative spikes = 33524
# step 500/1000, cumulative spikes = 41885
# step 600/1000, cumulative spikes = 49937
# step 700/1000, cumulative spikes = 59147
# step 800/1000, cumulative spikes = 67125
# step 900/1000, cumulative spikes = 74427
# step 1000/1000, cumulative spikes = 82200

# %%
net_8.analyze_covariance()
# Out:
# (array([[ 2.51339201e-05,  1.40751046e-06,  3.57252008e-06, ...,
#           2.44261076e-06,  2.08259991e-06,  1.65956886e-06],
#         [ 1.40751046e-06,  2.72846779e-05,  1.05670640e-06, ...,
#           2.19416817e-06,  1.59231209e-06,  2.83228508e-06],
#         [ 3.57252008e-06,  1.05670640e-06,  2.35408919e-05, ...,
#           1.40249526e-06, -9.45178123e-07, -1.92779741e-07],
#         ...,
#         [ 2.44261076e-06,  2.19416817e-06,  1.40249526e-06, ...,
#           2.80377947e-05,  2.91473762e-06,  1.93022029e-06],
#         [ 2.08259991e-06,  1.59231209e-06, -9.45178123e-07, ...,
#           2.91473762e-06,  2.20244936e-05,  1.61590256e-06],
#         [ 1.65956886e-06,  2.83228508e-06, -1.92779741e-07, ...,
#           1.93022029e-06,  1.61590256e-06,  2.45764821e-05]]),
#  array([ 1.79125950e+01,  4.52416749e-01,  2.35267868e-01, ...,
#         -1.78829889e-16, -3.32213579e-16, -2.31282294e-15]),
#  array([1.40751046e-06, 3.57252008e-06, 2.43664724e-06, ...,
# ...
